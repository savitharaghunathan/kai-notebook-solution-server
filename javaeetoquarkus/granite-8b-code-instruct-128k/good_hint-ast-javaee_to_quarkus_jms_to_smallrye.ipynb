# %% [markdown]
# # Hint Strategy 1
# This notebook demonstrates how an LLM performs when presented with a Javaee -> Quarkus JMS issue and provide a hint that can be used to improve the basic rule.
# Installing pre requisites and configuring Kai with `GPT-4o-mini`

# %%
# %pip uninstall kai -y
# %pip install --no-cache-dir git+https://github.com/konveyor/kai.git@main
# %pip install python-dotenv
# Out:
# Found existing installation: kai 0.1.1rc0
# Uninstalling kai-0.1.1rc0:
#   Successfully uninstalled kai-0.1.1rc0
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/konveyor/kai.git@main
#   Cloning https://github.com/konveyor/kai.git (to revision main) to /private/var/folders/4f/bv2hh9jd44b94_4zf2qby2sh0000gn/T/pip-req-build-fpna8kcz
#   Running command git clone --filter=blob:none --quiet https://github.com/konveyor/kai.git /private/var/folders/4f/bv2hh9jd44b94_4zf2qby2sh0000gn/T/pip-req-build-fpna8kcz
#   Resolved https://github.com/konveyor/kai.git to commit 923abc35262ed0e36094c91ee20f2e0cabc3bbf5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: aiohttp==3.9.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (3.9.3)
# Requirement already satisfied: gitpython==3.1.43 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (3.1.43)
# Requirement already satisfied: pydantic==2.10.6 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (2.10.6)
# Requirement already satisfied: pydantic-settings==2.4.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (2.4.0)
# Requirement already satisfied: requests==2.32.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (2.32.3)
# Requirement already satisfied: pygments==2.18.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (2.18.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (2.8.2)
# Requirement already satisfied: Jinja2==3.1.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (3.1.4)
# Requirement already satisfied: langchain==0.3.19 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.3.19)
# Requirement already satisfied: langchain-community==0.3.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.3.1)
# Requirement already satisfied: langchain-openai==0.3.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.3.3)
# Requirement already satisfied: langchain-ollama==0.2.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.2.3)
# Requirement already satisfied: langchain-google-genai==2.0.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (2.0.9)
# Requirement already satisfied: langchain-aws==0.2.11 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.2.11)
# Requirement already satisfied: langchain-experimental==0.3.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.3.2)
# Requirement already satisfied: langchain-deepseek-official==0.1.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.1.0)
# Requirement already satisfied: gunicorn==22.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (22.0.0)
# Requirement already satisfied: tree-sitter==0.22.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.22.3)
# Requirement already satisfied: tree-sitter-java==0.21.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.21.0)
# Requirement already satisfied: sequoia-diff>=0.0.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.0.9)
# Requirement already satisfied: python-dotenv==1.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (1.0.1)
# Requirement already satisfied: pyyaml==6.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (6.0.1)
# Requirement already satisfied: lxml==5.3.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (5.3.0)
# Requirement already satisfied: boto3==1.36.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (1.36.9)
# Requirement already satisfied: opentelemetry-sdk==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (1.29.0)
# Requirement already satisfied: opentelemetry-api==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-asyncio==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.50b0)
# Requirement already satisfied: async-timeout==4.0.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (4.0.3)
# Requirement already satisfied: asgiref==3.7.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (3.7.2)
# Requirement already satisfied: unidiff==0.7.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1rc0) (0.7.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1rc0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1rc0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1rc0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1rc0) (6.4.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1rc0) (1.20.0)
# Requirement already satisfied: botocore<1.37.0,>=1.36.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from boto3==1.36.9->kai==0.1.1rc0) (1.36.26)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from boto3==1.36.9->kai==0.1.1rc0) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from boto3==1.36.9->kai==0.1.1rc0) (0.11.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from gitpython==3.1.43->kai==0.1.1rc0) (4.0.12)
# Requirement already satisfied: packaging in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from gunicorn==22.0.0->kai==0.1.1rc0) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from Jinja2==3.1.4->kai==0.1.1rc0) (3.0.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.35 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1rc0) (0.3.53)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1rc0) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1rc0) (0.1.147)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1rc0) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1rc0) (8.5.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1rc0) (1.26.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-community==0.3.1->kai==0.1.1rc0) (0.6.7)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-google-genai==2.0.9->kai==0.1.1rc0) (1.2.0)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-google-genai==2.0.9->kai==0.1.1rc0) (0.8.5)
# Requirement already satisfied: ollama<1,>=0.4.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-ollama==0.2.3->kai==0.1.1rc0) (0.4.8)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-openai==0.3.3->kai==0.1.1rc0) (1.75.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-openai==0.3.3->kai==0.1.1rc0) (0.9.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-api==1.29.0->kai==0.1.1rc0) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-api==1.29.0->kai==0.1.1rc0) (8.5.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp==1.29.0->kai==0.1.1rc0) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp==1.29.0->kai==0.1.1rc0) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asyncio==0.50b0->kai==0.1.1rc0) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asyncio==0.50b0->kai==0.1.1rc0) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asyncio==0.50b0->kai==0.1.1rc0) (1.17.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-sdk==1.29.0->kai==0.1.1rc0) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from pydantic==2.10.6->kai==0.1.1rc0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from pydantic==2.10.6->kai==0.1.1rc0) (2.27.2)
# Requirement already satisfied: six>=1.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from python-dateutil==2.8.2->kai==0.1.1rc0) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1rc0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1rc0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1rc0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1rc0) (2025.1.31)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1rc0) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1rc0) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1rc0) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1rc0) (1.29.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1rc0) (5.29.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1->kai==0.1.1rc0) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1->kai==0.1.1rc0) (0.9.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython==3.1.43->kai==0.1.1rc0) (5.0.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (0.6.15)
# Requirement already satisfied: google-api-core in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (2.24.2)
# Requirement already satisfied: google-api-python-client in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (2.167.0)
# Requirement already satisfied: google-auth>=2.15.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (2.39.0)
# Requirement already satisfied: tqdm in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (1.26.1)
# Requirement already satisfied: zipp>=3.20 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api==1.29.0->kai==0.1.1rc0) (3.21.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.35->langchain==0.3.19->kai==0.1.1rc0) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1rc0) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1rc0) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1rc0) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1rc0) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1rc0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1rc0) (0.9.0)
# Requirement already satisfied: sniffio in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1rc0) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.3->kai==0.1.1rc0) (2024.11.6)
# Requirement already satisfied: propcache>=0.2.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from yarl<2.0,>=1.0->aiohttp==3.9.3->kai==0.1.1rc0) (0.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (4.9.1)
# Requirement already satisfied: httpcore==1.* in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1rc0) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1rc0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.35->langchain==0.3.19->kai==0.1.1rc0) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1->kai==0.1.1rc0) (1.0.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (4.1.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1rc0) (0.6.1)
# Building wheels for collected packages: kai
#   Building wheel for kai (pyproject.toml) ... done
#   Created wheel for kai: filename=kai-0.1.1rc0-py3-none-any.whl size=4435614 sha256=17f55dec99e11609f778d39a147aaf212fb3cfcae6ce03ff4ff88c4ea7a169dd
#   Stored in directory: /private/var/folders/4f/bv2hh9jd44b94_4zf2qby2sh0000gn/T/pip-ephem-wheel-cache-jwn5nh5_/wheels/7a/5a/5e/746d82c99334b9ca71a121d123b53f96cb34d14e0b5280cb9a
# Successfully built kai
# Installing collected packages: kai
# Successfully installed kai-0.1.1rc0
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (1.0.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import display, Markdown
from kai.llm_interfacing.model_provider import ModelProvider
from kai.kai_config import KaiConfigModels, SupportedModelProviders
from dotenv import load_dotenv
import os
load_dotenv(override=True) 

# Initialize the model provider 
model = ModelProvider.from_config(KaiConfigModels(
    provider=SupportedModelProviders.CHAT_OPENAI,
    args={"model": "granite-8b-code-instruct-128k",
        "base_url": "https://granite-8b-code-instruct-maas-apicast-production.apps.prod.rhoai.rh-aiservices-bu.com:443/v1",
        "api_key": os.getenv("OPENAI_API_KEY"),
        "temperature": 0.1, },
))

# Async rendering function for displaying the response
async def rendered_llm_call(prompt: str):
    response = await model.ainvoke_llm(prompt)
    display(Markdown(response.content))
    return response

# %% [markdown]
# Below is the snippet we are trying to migrate from javaee to Qusrkus. This code uses JMS which needs to be migarted to Quarkus equivalent.
# Our goal is to assess how well the LLM refactors this configuration without a hint, and whether it can replace deprecated patterns with the right approach.

# %%
before_code = """\
import javax.jms.* 

public class InventoryNotificationMDB implements MessageListener {

    private static final int LOW_THRESHOLD = 50;

    @Inject
    private CatalogService catalogService;

    private final static String JNDI_FACTORY = "weblogic.jndi.WLInitialContextFactory";
    private final static String JMS_FACTORY = "TCF";
    private final static String TOPIC = "topic/orders";
    private TopicConnection tcon;
    private TopicSession tsession;
    private TopicSubscriber tsubscriber;

    public void onMessage(Message rcvMessage) {
        TextMessage msg;
        {
            try {
                System.out.println("received message inventory");
                if (rcvMessage instanceof TextMessage) {
                    msg = (TextMessage) rcvMessage;
                    String orderStr = msg.getBody(String.class);
                    Order order = Transformers.jsonToOrder(orderStr);
                    order.getItemList().forEach(orderItem -> {
                        int old_quantity = catalogService.getCatalogItemById(orderItem.getProductId()).getInventory().getQuantity();
                        int new_quantity = old_quantity - orderItem.getQuantity();
                        if (new_quantity < LOW_THRESHOLD) {
                            System.out.println("Inventory for item " + orderItem.getProductId() + " is below threshold (" + LOW_THRESHOLD + "), contact supplier!");
                        } else {
                            orderItem.setQuantity(new_quantity);
                        }
                    });
                }


            } catch (JMSException jmse) {
                System.err.println("An exception occurred: " + jmse.getMessage());
            }
        }
    }
    }
"""

# %% [markdown]
# This rule flags suggests migrating javaee JMS referesnces with Quarkus specific ones.

# %%
hint_to_migrate="""\
    
  description:  References to JavaEE/JakartaEE JMS elements should be removed and replaced with their Quarkus SmallRye/Microprofile equivalents.
  message: |
   References to JavaEE/JakartaEE JMS elements should be removed and replaced with their Quarkus SmallRye/Microprofile equivalents.

General Guidance:

* Always replace Java EE components with their Quarkus/MicroProfile equivalents.
* Use annotations like @Incoming for message consumption and @ApplicationScoped for bean management.
* Implement logging using org.jboss.logging.Logger for better integration with Quarkus.
* Ensure that error handling is robust and follows Quarkus practices, potentially using @Transactional for methods that modify state.

Optional Changes:

* Consider using reactive programming patterns where applicable.
* Review the need for additional configuration or properties in application.properties for message brokers or other services.
    """

# %% [markdown]
# Similar example showing before and after migration

# %%
example_before_code="""\

@MessageDriven(
    activationConfig = {
        @ActivationConfigProperty(propertyName = "destinationLookup", propertyValue = "jms/queue/myQueue"), // JNDI lookup
        @ActivationConfigProperty(propertyName = "destinationType", propertyValue = "jakarta.jms.Queue")
        // Other properties like connectionFactoryLookup, acknowledgeMode might be needed depending on the server
    }
)
public class SimpleQueueMDB implements MessageListener {

    private static final Logger log = Logger.getLogger(SimpleQueueMDB.class.getName());

    @Override
    public void onMessage(Message message) {
        try {
            if (message instanceof TextMessage) {
                TextMessage textMessage = (TextMessage) message;
                String text = textMessage.getText();
                log.log(Level.INFO, "MDB Received: {0}", text);
               
                processPayload(text);
            } else {
                log.log(Level.WARNING, "MDB Received non-text message: {0}", message);
            }
            // Container typically acknowledges based on configuration (default AUTO_ACKNOWLEDGE implicit here)
        } catch (Exception e) {
            log.log(Level.SEVERE, "MDB Error processing message", e);

        }
    }
}

"""

example_after_code="""\
import jakarta.enterprise.context.ApplicationScoped;
import org.eclipse.microprofile.reactive.messaging.Incoming;
import org.jboss.logging.Logger;

@ApplicationScoped
public class SimpleQueueListener {

    private static final Logger log = Logger.getLogger(SimpleQueueListener.class);
    @Incoming("my-queue-in")
    public void consume(String payload) { 
        log.infof("Reactive Listener Received: %s", payload);
        try {

            processPayload(payload);

        } catch (Exception e) {
            log.errorf(e, "Reactive Listener Error processing message: %s", payload);
            throw new RuntimeException("Processing failed for: " + payload, e);
        }
    }

}

"""

example_before_code_2 = """\

import javax.ejb.ActivationConfigProperty;
import javax.ejb.MessageDriven;
import javax.ejb.TransactionAttribute;
import javax.ejb.TransactionAttributeType;
import javax.inject.Inject; 
import javax.jms.JMSException;
import javax.jms.Message;
import javax.jms.MessageListener;
import javax.jms.TextMessage;
import javax.persistence.EntityManager; 
import javax.persistence.PersistenceContext; 
import java.util.logging.Level;
import java.util.logging.Logger;

@MessageDriven(
    activationConfig = {
        @ActivationConfigProperty(propertyName = "destinationLookup", propertyValue = "jms/queue/orderQueue"),
        @ActivationConfigProperty(propertyName = "destinationType", propertyValue = "javax.jms.Queue") // javax.jms.Queue
    }
)
public class TransactionalOrderMDB implements MessageListener {

    private static final Logger log = Logger.getLogger(TransactionalOrderMDB.class.getName());

    @PersistenceContext 
    EntityManager em;

    @Override
    @TransactionAttribute(TransactionAttributeType.REQUIRED) 
    public void onMessage(Message message) {
        log.info("Java EE (javax) MDB: Received transactional message.");
        try {
            if (message instanceof TextMessage) {
                TextMessage textMessage = (TextMessage) message;
                String orderData = textMessage.getText();
                log.log(Level.INFO, "Java EE (javax) MDB Received Order Data: {0}", orderData);
                saveOrder(orderData);
                log.log(Level.INFO, "Java EE (javax) MDB Order saved.");
            }
        } catch (JMSException e) { 
            log.log(Level.SEVERE, "Java EE (javax) MDB JMS Error, TX rolling back", e);
            throw new RuntimeException(e); 
        } catch (Exception e) {
            log.log(Level.SEVERE, "Java EE (javax) MDB Processing Error, TX rolling back", e);
            throw new RuntimeException(e); 
        }
    }

    private void saveOrder(String orderData) {
        log.log(Level.INFO, "Java EE (javax) MDB Saving order: {0}", orderData);
        
    }
}
"""

example_after_code_2= """\

import jakarta.enterprise.context.ApplicationScoped;
import jakarta.inject.Inject; 
import jakarta.persistence.EntityManager;
import jakarta.transaction.Transactional; 
import org.eclipse.microprofile.reactive.messaging.Incoming;
import org.jboss.logging.Logger;

@ApplicationScoped
public class TransactionalOrderListener {

    private static final Logger log = Logger.getLogger(TransactionalOrderListener.class);

    @Inject
    EntityManager em; 

    @Incoming("order-queue-in")
    @Transactional 
    public void consume(String orderData) {
        log.infof("Quarkus Reactive Received Order Data: %s", orderData);
        try {
            saveOrder(orderData);
            log.info("Quarkus Reactive Order saved successfully.");
            
        } catch (Exception e) {
            log.errorf(e, "Quarkus Reactive Error processing order, TX will roll back");
            throw new RuntimeException("Order processing failed for: " + orderData, e);
        }
    }

    private void saveOrder(String orderData) {
        log.infof("Quarkus Reactive Saving order: %s", orderData);
       
    }
}

"""

example_before_code_3 ="""\

import javax.ejb.ActivationConfigProperty;
import javax.ejb.MessageDriven;
import javax.jms.JMSException;
import javax.jms.Message;
import javax.jms.MessageListener;
import javax.jms.TextMessage;
import java.util.logging.Level;
import java.util.logging.Logger;

@MessageDriven(
    activationConfig = {
        @ActivationConfigProperty(propertyName = "destinationLookup", propertyValue = "jms/queue/processingQueue"),
        @ActivationConfigProperty(propertyName = "destinationType", propertyValue = "javax.jms.Queue") // javax.jms.Queue
    }
)
public class BlockingWorkMDB implements MessageListener {

    private static final Logger log = Logger.getLogger(BlockingWorkMDB.class.getName());

    @Override
    public void onMessage(Message message) {
        log.info("Java EE (javax) MDB: Received message for blocking work.");
        try {
            if (message instanceof TextMessage) {
                TextMessage textMessage = (TextMessage) message;
                String data = textMessage.getText();
                log.log(Level.INFO, "Java EE (javax) MDB Received Data: {0}", data);
                callSlowExternalService(data);
                log.log(Level.INFO, "Java EE (javax) MDB Blocking work finished for: {0}", data);
            }
        } catch (JMSException e) { 
            log.log(Level.SEVERE, "Java EE (javax) MDB JMS Error during blocking work", e);
        } catch (Exception e) {
             log.log(Level.SEVERE, "Java EE (javax) MDB Error during blocking work", e);
        }
    }

    private void callSlowExternalService(String data) throws InterruptedException {
        log.log(Level.INFO, "Java EE (javax) MDB Starting slow operation for: {0}...", data);
        Thread.sleep(2000);
        log.log(Level.INFO, "...Java EE (javax) MDB Finished slow operation for: {0}", data);
    }
}
"""

example_after_code_3="""\
package com.example.quarkus;

import jakarta.enterprise.context.ApplicationScoped;
import org.eclipse.microprofile.reactive.messaging.Incoming;
import io.smallrye.reactive.messaging.annotations.Blocking; 
import org.jboss.logging.Logger;

@ApplicationScoped
public class BlockingWorkListener {

    private static final Logger log = Logger.getLogger(BlockingWorkListener.class);

    @Incoming("processing-queue-in")
    @Blocking 
    public void consumeAndBlock(String data) throws InterruptedException {
        log.infof("Quarkus Reactive Received Data: %s", data);
        try {
           
            callSlowExternalService(data);
            log.infof("Quarkus Reactive Blocking work finished for: %s", data);
        } catch (InterruptedException ie) {
             log.warnf("Quarkus Reactive Blocking operation interrupted for %s", data);
             Thread.currentThread().interrupt();
             throw new RuntimeException(ie);
        } catch (Exception e) {
            log.errorf(e, "Quarkus Reactive Error during blocking work for: %s", data);
            throw new RuntimeException("Blocking processing failed for: " + data, e);
        }
    }

    private void callSlowExternalService(String data) throws InterruptedException {
        log.infof("Quarkus Reactive Starting slow operation for: %s...", data);
        Thread.sleep(2000); 
        log.infof("...Quarkus Reactive Finished slow operation for: %s", data);
    }
}

"""

# %%
from kai.reactive_codeplanner.agent.reflection_agent import extract_ast_info, Language

original_summary = extract_ast_info(example_before_code, language=Language.Java)
original_summary_2 = extract_ast_info(example_before_code_2, language=Language.Java)
original_summary_3 = extract_ast_info(example_before_code_3, language=Language.Java)
updated_summary = extract_ast_info(example_after_code, language=Language.Java)
updated_summary_2 = extract_ast_info(example_after_code_2, language=Language.Java)
updated_summary_3 = extract_ast_info(example_after_code_3, language=Language.Java)

diff = original_summary.diff(updated_summary)
diff2 = original_summary_2.diff(updated_summary_2)
diff3 = original_summary_3.diff(updated_summary_3)

print(diff)
print(diff2)
print(diff3)
# Out:
# {'imports': {'old': [], 'new': ['org.jboss.logging.Logger', 'jakarta.enterprise.context.ApplicationScoped', 'org.eclipse.microprofile.reactive.messaging.Incoming']}, 'classes': {'added': [{'name': 'SimpleQueueListener', 'annotations': [{'name': 'ApplicationScoped'}], 'fields': {'9174546538122367342': {'name': 'log', 'type': 'Logger'}}, 'methods': {'-6834099951837437557': {'name': 'consume', 'parameters': '(String payload)', 'body': '{ \n        log.infof("Reactive Listener Received: %s", payload);\n        try {\n\n            processPayload(payload);\n\n        } catch (Exception e) {\n            log.errorf(e, "Reactive Listener Error processing message: %s", payload);\n            throw new RuntimeException("Processing failed for: " + payload, e);\n        }\n    }', 'annotations': [{'name': 'Incoming', 'parameters': '("my-queue-in")'}]}}}], 'removed': [{'name': 'SimpleQueueMDB', 'interfaces': ['MessageListener', 'implements'], 'annotations': [{'name': 'MessageDriven', 'parameters': '(\n    activationConfig = {\n        @ActivationConfigProperty(propertyName = "destinationLookup", propertyValue = "jms/queue/myQueue"), // JNDI lookup\n        @ActivationConfigProperty(propertyName = "destinationType", propertyValue = "jakarta.jms.Queue")\n        // Other properties like connectionFactoryLookup, acknowledgeMode might be needed depending on the server\n    }\n)'}], 'fields': {'9174546538122367342': {'name': 'log', 'type': 'Logger'}}, 'methods': {'-1016107944021043122': {'name': 'onMessage', 'parameters': '(Message message)', 'body': '{\n        try {\n            if (message instanceof TextMessage) {\n                TextMessage textMessage = (TextMessage) message;\n                String text = textMessage.getText();\n                log.log(Level.INFO, "MDB Received: {0}", text);\n\n                processPayload(text);\n            } else {\n                log.log(Level.WARNING, "MDB Received non-text message: {0}", message);\n            }\n            // Container typically acknowledges based on configuration (default AUTO_ACKNOWLEDGE implicit here)\n        } catch (Exception e) {\n            log.log(Level.SEVERE, "MDB Error processing message", e);\n\n        }\n    }', 'annotations': [{'name': 'Override'}]}}}]}}
# {'imports': {'old': ['javax.ejb.ActivationConfigProperty', 'javax.jms.Message', 'javax.jms.TextMessage', 'javax.persistence.EntityManager', 'javax.ejb.TransactionAttributeType', 'java.util.logging.Level', 'javax.inject.Inject', 'javax.persistence.PersistenceContext', 'javax.jms.JMSException', 'javax.jms.MessageListener', 'javax.ejb.MessageDriven', 'javax.ejb.TransactionAttribute', 'java.util.logging.Logger'], 'new': ['jakarta.enterprise.context.ApplicationScoped', 'org.jboss.logging.Logger', 'jakarta.persistence.EntityManager', 'jakarta.transaction.Transactional', 'org.eclipse.microprofile.reactive.messaging.Incoming', 'jakarta.inject.Inject']}, 'classes': {'added': [{'name': 'TransactionalOrderListener', 'annotations': [{'name': 'ApplicationScoped'}], 'fields': {'9174546538122367342': {'name': 'log', 'type': 'Logger'}, '-4813484180665495070': {'name': 'em', 'type': 'EntityManager', 'annotations': [{'name': 'Inject'}]}}, 'methods': {'-6834099951837437557': {'name': 'consume', 'parameters': '(String orderData)', 'body': '{\n        log.infof("Quarkus Reactive Received Order Data: %s", orderData);\n        try {\n            saveOrder(orderData);\n            log.info("Quarkus Reactive Order saved successfully.");\n\n        } catch (Exception e) {\n            log.errorf(e, "Quarkus Reactive Error processing order, TX will roll back");\n            throw new RuntimeException("Order processing failed for: " + orderData, e);\n        }\n    }', 'annotations': [{'name': 'Incoming', 'parameters': '("order-queue-in")'}, {'name': 'Transactional'}]}, '-5239539289726100401': {'name': 'saveOrder', 'parameters': '(String orderData)', 'body': '{\n        log.infof("Quarkus Reactive Saving order: %s", orderData);\n\n    }'}}}], 'removed': [{'name': 'TransactionalOrderMDB', 'interfaces': ['MessageListener', 'implements'], 'annotations': [{'name': 'MessageDriven', 'parameters': '(\n    activationConfig = {\n        @ActivationConfigProperty(propertyName = "destinationLookup", propertyValue = "jms/queue/orderQueue"),\n        @ActivationConfigProperty(propertyName = "destinationType", propertyValue = "javax.jms.Queue") // javax.jms.Queue\n    }\n)'}], 'fields': {'9174546538122367342': {'name': 'log', 'type': 'Logger'}, '-4813484180665495070': {'name': 'em', 'type': 'EntityManager', 'annotations': [{'name': 'PersistenceContext'}]}}, 'methods': {'-1016107944021043122': {'name': 'onMessage', 'parameters': '(Message message)', 'body': '{\n        log.info("Java EE (javax) MDB: Received transactional message.");\n        try {\n            if (message instanceof TextMessage) {\n                TextMessage textMessage = (TextMessage) message;\n                String orderData = textMessage.getText();\n                log.log(Level.INFO, "Java EE (javax) MDB Received Order Data: {0}", orderData);\n                saveOrder(orderData);\n                log.log(Level.INFO, "Java EE (javax) MDB Order saved.");\n            }\n        } catch (JMSException e) { \n            log.log(Level.SEVERE, "Java EE (javax) MDB JMS Error, TX rolling back", e);\n            throw new RuntimeException(e); \n        } catch (Exception e) {\n            log.log(Level.SEVERE, "Java EE (javax) MDB Processing Error, TX rolling back", e);\n            throw new RuntimeException(e); \n        }\n    }', 'annotations': [{'name': 'Override'}, {'name': 'TransactionAttribute', 'parameters': '(TransactionAttributeType.REQUIRED)'}]}, '-5239539289726100401': {'name': 'saveOrder', 'parameters': '(String orderData)', 'body': '{\n        log.log(Level.INFO, "Java EE (javax) MDB Saving order: {0}", orderData);\n\n    }'}}}]}}
# {'imports': {'old': ['javax.ejb.ActivationConfigProperty', 'javax.jms.Message', 'javax.jms.TextMessage', 'java.util.logging.Level', 'javax.jms.MessageListener', 'javax.jms.JMSException', 'javax.ejb.MessageDriven', 'java.util.logging.Logger'], 'new': ['org.jboss.logging.Logger', 'jakarta.enterprise.context.ApplicationScoped', 'io.smallrye.reactive.messaging.annotations.Blocking', 'org.eclipse.microprofile.reactive.messaging.Incoming']}, 'classes': {'added': [{'name': 'BlockingWorkListener', 'annotations': [{'name': 'ApplicationScoped'}], 'fields': {'9174546538122367342': {'name': 'log', 'type': 'Logger'}}, 'methods': {'98024130418629610': {'name': 'consumeAndBlock', 'parameters': '(String data)', 'body': '{\n        log.infof("Quarkus Reactive Received Data: %s", data);\n        try {\n\n            callSlowExternalService(data);\n            log.infof("Quarkus Reactive Blocking work finished for: %s", data);\n        } catch (InterruptedException ie) {\n             log.warnf("Quarkus Reactive Blocking operation interrupted for %s", data);\n             Thread.currentThread().interrupt();\n             throw new RuntimeException(ie);\n        } catch (Exception e) {\n            log.errorf(e, "Quarkus Reactive Error during blocking work for: %s", data);\n            throw new RuntimeException("Blocking processing failed for: " + data, e);\n        }\n    }', 'annotations': [{'name': 'Incoming', 'parameters': '("processing-queue-in")'}, {'name': 'Blocking'}]}, '-5567581906243612337': {'name': 'callSlowExternalService', 'parameters': '(String data)', 'body': '{\n        log.infof("Quarkus Reactive Starting slow operation for: %s...", data);\n        Thread.sleep(2000); \n        log.infof("...Quarkus Reactive Finished slow operation for: %s", data);\n    }'}}}], 'removed': [{'name': 'BlockingWorkMDB', 'interfaces': ['MessageListener', 'implements'], 'annotations': [{'name': 'MessageDriven', 'parameters': '(\n    activationConfig = {\n        @ActivationConfigProperty(propertyName = "destinationLookup", propertyValue = "jms/queue/processingQueue"),\n        @ActivationConfigProperty(propertyName = "destinationType", propertyValue = "javax.jms.Queue") // javax.jms.Queue\n    }\n)'}], 'fields': {'9174546538122367342': {'name': 'log', 'type': 'Logger'}}, 'methods': {'-1016107944021043122': {'name': 'onMessage', 'parameters': '(Message message)', 'body': '{\n        log.info("Java EE (javax) MDB: Received message for blocking work.");\n        try {\n            if (message instanceof TextMessage) {\n                TextMessage textMessage = (TextMessage) message;\n                String data = textMessage.getText();\n                log.log(Level.INFO, "Java EE (javax) MDB Received Data: {0}", data);\n                callSlowExternalService(data);\n                log.log(Level.INFO, "Java EE (javax) MDB Blocking work finished for: {0}", data);\n            }\n        } catch (JMSException e) { \n            log.log(Level.SEVERE, "Java EE (javax) MDB JMS Error during blocking work", e);\n        } catch (Exception e) {\n             log.log(Level.SEVERE, "Java EE (javax) MDB Error during blocking work", e);\n        }\n    }', 'annotations': [{'name': 'Override'}]}, '-5567581906243612337': {'name': 'callSlowExternalService', 'parameters': '(String data)', 'body': '{\n        log.log(Level.INFO, "Java EE (javax) MDB Starting slow operation for: {0}...", data);\n        Thread.sleep(2000);\n        log.log(Level.INFO, "...Java EE (javax) MDB Finished slow operation for: {0}", data);\n    }'}}}]}}

# %%
source="javaee"
target="quarkus, jakarta-ee"

# %%
prompt = f"""

You are assisting with migrating from {source} to {target}.

The code that needs migration is:

```java
{before_code}
```

You are given:

* A diff between a before/after successful **example** migrations.

* An hint that describes what should change.

Diff (use this as a guiding pattern for migration) - {diff} {diff2} {diff3}

Rule Hint - {hint_to_migrate}

Task

Refactor the given code {before_code} to make it compatible with {target}.

Ensure deprecated or removed APIs are replaced with valid alternatives.

1. Analyze:

Review the before-code, diff, summary, and hint carefully.

Identify and list any deprecated, removed, or outdated methods, APIs, libraries, or coding patterns present in the before-code.

Identify any missing constructs required for compatibility with {target}.

2. Refactor:

Migrate the provided code fully to be compatible with {target}.

Remove deprecated APIs and replace them with appropriate alternatives.

Follow {target} best practices for configuration and structure.

Ensure the code is modular, clean, maintainable, and production-grade — not just minimal.

3. Validate:

Confirm that the refactored code is compilable and correct for {target}.

Confirm that no deprecated methods, imports, or patterns remain.

Confirm that configuration and new standards are applied correctly.

Confirm that imports or package references match the correct updated libraries.

4. Output:

* Refactored Code in Java

* New Hint Summary to guide future similar migrations. Include optional changes that may be needed

"""

# %%
response = await rendered_llm_call(prompt)
# Out:
# Here is the refactored code for the given problem:
#
# ```java
# import org.jboss.logging.Logger;
# import jakarta.enterprise.context.ApplicationScoped;
# import io.smallrye.reactive.messaging.annotations.Incoming;
#
# @ApplicationScoped
# public class InventoryNotificationListener {
#
#     private static final int LOW_THRESHOLD = 50;
#
#     @Inject
#     private CatalogService catalogService;
#
#     private static final Logger log = Logger.getLogger(InventoryNotificationListener.class);
#
#     @Incoming("orders")
#     public void consume(String orderStr) {
#         Order order = Transformers.jsonToOrder(orderStr);
#         order.getItemList().forEach(orderItem -> {
#             int old_quantity = catalogService.getCatalogItemById(orderItem.getProductId()).getInventory().getQuantity();
#             int new_quantity = old_quantity - orderItem.getQuantity();
#             if (new_quantity < LOW_THRESHOLD) {
#                 log.infof("Inventory for item %s is below threshold (%s), contact supplier!", orderItem.getProductId(), LOW_THRESHOLD);
#             } else {
#                 orderItem.setQuantity(new_quantity);
#             }
#         });
#     }
# }
# ```
#
# In this refactored code, the deprecated or removed APIs and libraries have been replaced with their Quarkus/MicroProfile equivalents. The code follows quarkus, jakarta-ee best practices for configuration and structure. The code is modular, clean, maintainable, and production-grade.
#
# The hint summary for this migration is:
#
# "References to JavaEE/JakartaEE JMS elements should be removed and replaced with their Quarkus SmallRye/Microprofile equivalents."
#
# This hint provides guidance for future migrations by highlighting the need to replace deprecated or removed APIs and libraries with their Quarkus/MicroProfile equivalents.
