# %% [markdown]
# # Hint Strategy 1
# This notebook demonstrates how an LLM performs when presented with a Javaee -> Quarkus JMS issue and provide a hint that can be used to improve the basic rule.
# Installing pre requisites and configuring Kai with `GPT-4o-mini`

# %%
# %pip uninstall kai -y
# %pip install --no-cache-dir git+https://github.com/konveyor/kai.git@main
# %pip install python-dotenv
# Out:
# Found existing installation: kai 0.1.1.dev8+g923abc3
# Uninstalling kai-0.1.1.dev8+g923abc3:
#   Successfully uninstalled kai-0.1.1.dev8+g923abc3
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/konveyor/kai.git@main
#   Cloning https://github.com/konveyor/kai.git (to revision main) to /private/var/folders/4f/bv2hh9jd44b94_4zf2qby2sh0000gn/T/pip-req-build-rhw45l2i
#   Running command git clone --filter=blob:none --quiet https://github.com/konveyor/kai.git /private/var/folders/4f/bv2hh9jd44b94_4zf2qby2sh0000gn/T/pip-req-build-rhw45l2i
#   Resolved https://github.com/konveyor/kai.git to commit 923abc35262ed0e36094c91ee20f2e0cabc3bbf5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: aiohttp==3.9.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (3.9.3)
# Requirement already satisfied: gitpython==3.1.43 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (3.1.43)
# Requirement already satisfied: pydantic==2.10.6 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (2.10.6)
# Requirement already satisfied: pydantic-settings==2.4.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (2.4.0)
# Requirement already satisfied: requests==2.32.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (2.32.3)
# Requirement already satisfied: pygments==2.18.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (2.18.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (2.8.2)
# Requirement already satisfied: Jinja2==3.1.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (3.1.4)
# Requirement already satisfied: langchain==0.3.19 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.3.19)
# Requirement already satisfied: langchain-community==0.3.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.3.1)
# Requirement already satisfied: langchain-openai==0.3.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.3.3)
# Requirement already satisfied: langchain-ollama==0.2.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.2.3)
# Requirement already satisfied: langchain-google-genai==2.0.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (2.0.9)
# Requirement already satisfied: langchain-aws==0.2.11 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.2.11)
# Requirement already satisfied: langchain-experimental==0.3.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.3.2)
# Requirement already satisfied: langchain-deepseek-official==0.1.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.1.0)
# Requirement already satisfied: gunicorn==22.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (22.0.0)
# Requirement already satisfied: tree-sitter==0.22.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.22.3)
# Requirement already satisfied: tree-sitter-java==0.21.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.21.0)
# Requirement already satisfied: sequoia-diff>=0.0.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.0.9)
# Requirement already satisfied: python-dotenv==1.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (1.0.1)
# Requirement already satisfied: pyyaml==6.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (6.0.1)
# Requirement already satisfied: lxml==5.3.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (5.3.0)
# Requirement already satisfied: boto3==1.36.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (1.36.9)
# Requirement already satisfied: opentelemetry-sdk==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (1.29.0)
# Requirement already satisfied: opentelemetry-api==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-asyncio==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.50b0)
# Requirement already satisfied: async-timeout==4.0.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (4.0.3)
# Requirement already satisfied: asgiref==3.7.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (3.7.2)
# Requirement already satisfied: unidiff==0.7.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev8+g923abc3) (0.7.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1.dev8+g923abc3) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1.dev8+g923abc3) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1.dev8+g923abc3) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1.dev8+g923abc3) (6.4.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1.dev8+g923abc3) (1.20.0)
# Requirement already satisfied: botocore<1.37.0,>=1.36.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from boto3==1.36.9->kai==0.1.1.dev8+g923abc3) (1.36.26)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from boto3==1.36.9->kai==0.1.1.dev8+g923abc3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from boto3==1.36.9->kai==0.1.1.dev8+g923abc3) (0.11.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from gitpython==3.1.43->kai==0.1.1.dev8+g923abc3) (4.0.12)
# Requirement already satisfied: packaging in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from gunicorn==22.0.0->kai==0.1.1.dev8+g923abc3) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from Jinja2==3.1.4->kai==0.1.1.dev8+g923abc3) (3.0.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.35 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (0.3.53)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (0.1.147)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (8.5.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (1.26.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-community==0.3.1->kai==0.1.1.dev8+g923abc3) (0.6.7)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (1.2.0)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (0.8.5)
# Requirement already satisfied: ollama<1,>=0.4.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-ollama==0.2.3->kai==0.1.1.dev8+g923abc3) (0.4.8)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-openai==0.3.3->kai==0.1.1.dev8+g923abc3) (1.75.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-openai==0.3.3->kai==0.1.1.dev8+g923abc3) (0.9.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-api==1.29.0->kai==0.1.1.dev8+g923abc3) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-api==1.29.0->kai==0.1.1.dev8+g923abc3) (8.5.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev8+g923abc3) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev8+g923abc3) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asyncio==0.50b0->kai==0.1.1.dev8+g923abc3) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asyncio==0.50b0->kai==0.1.1.dev8+g923abc3) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asyncio==0.50b0->kai==0.1.1.dev8+g923abc3) (1.17.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-sdk==1.29.0->kai==0.1.1.dev8+g923abc3) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from pydantic==2.10.6->kai==0.1.1.dev8+g923abc3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from pydantic==2.10.6->kai==0.1.1.dev8+g923abc3) (2.27.2)
# Requirement already satisfied: six>=1.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from python-dateutil==2.8.2->kai==0.1.1.dev8+g923abc3) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1.dev8+g923abc3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1.dev8+g923abc3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1.dev8+g923abc3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1.dev8+g923abc3) (2025.1.31)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev8+g923abc3) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev8+g923abc3) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev8+g923abc3) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev8+g923abc3) (1.29.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev8+g923abc3) (5.29.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1->kai==0.1.1.dev8+g923abc3) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1->kai==0.1.1.dev8+g923abc3) (0.9.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython==3.1.43->kai==0.1.1.dev8+g923abc3) (5.0.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (0.6.15)
# Requirement already satisfied: google-api-core in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (2.24.2)
# Requirement already satisfied: google-api-python-client in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (2.167.0)
# Requirement already satisfied: google-auth>=2.15.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (2.39.0)
# Requirement already satisfied: tqdm in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (1.26.1)
# Requirement already satisfied: zipp>=3.20 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api==1.29.0->kai==0.1.1.dev8+g923abc3) (3.21.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.35->langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1.dev8+g923abc3) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1.dev8+g923abc3) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1.dev8+g923abc3) (0.9.0)
# Requirement already satisfied: sniffio in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1.dev8+g923abc3) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.3->kai==0.1.1.dev8+g923abc3) (2024.11.6)
# Requirement already satisfied: propcache>=0.2.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from yarl<2.0,>=1.0->aiohttp==3.9.3->kai==0.1.1.dev8+g923abc3) (0.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (4.9.1)
# Requirement already satisfied: httpcore==1.* in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.35->langchain==0.3.19->kai==0.1.1.dev8+g923abc3) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1->kai==0.1.1.dev8+g923abc3) (1.0.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (4.1.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev8+g923abc3) (0.6.1)
# Building wheels for collected packages: kai
#   Building wheel for kai (pyproject.toml) ... done
#   Created wheel for kai: filename=kai-0.1.1.dev8+g923abc3-py3-none-any.whl size=4435742 sha256=ecae9c70eb14e1e4533dc16cdcd6f926b10e615aaf4221c9851adf760f9882eb
#   Stored in directory: /private/var/folders/4f/bv2hh9jd44b94_4zf2qby2sh0000gn/T/pip-ephem-wheel-cache-grgmoot8/wheels/7a/5a/5e/746d82c99334b9ca71a121d123b53f96cb34d14e0b5280cb9a
# Successfully built kai
# Installing collected packages: kai
# Successfully installed kai-0.1.1.dev8+g923abc3
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (1.0.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import display, Markdown
from kai.llm_interfacing.model_provider import ModelProvider
from kai.kai_config import KaiConfigModels, SupportedModelProviders
from dotenv import load_dotenv
load_dotenv() 

# Initialize the model provider using GPT-4o via OpenAI
model = ModelProvider.from_config(KaiConfigModels(
    provider=SupportedModelProviders.CHAT_OPENAI,
    args={"model": "gpt-3.5-turbo"},
))

# Async rendering function for displaying the response
async def rendered_llm_call(prompt: str):
    response = await model.ainvoke_llm(prompt)
    display(Markdown(response.content))
    return response

# %% [markdown]
# Below is the snippet we are trying to migrate from javaee to Qusrkus. This code uses JMS which needs to be migarted to Quarkus equivalent.
# Our goal is to assess how well the LLM refactors this configuration without a hint, and whether it can replace deprecated patterns with the right approach.

# %%
before_code = """\
import javax.jms.* 

public class InventoryNotificationMDB implements MessageListener {

    private static final int LOW_THRESHOLD = 50;

    @Inject
    private CatalogService catalogService;

    private final static String JNDI_FACTORY = "weblogic.jndi.WLInitialContextFactory";
    private final static String JMS_FACTORY = "TCF";
    private final static String TOPIC = "topic/orders";
    private TopicConnection tcon;
    private TopicSession tsession;
    private TopicSubscriber tsubscriber;

    public void onMessage(Message rcvMessage) {
        TextMessage msg;
        {
            try {
                System.out.println("received message inventory");
                if (rcvMessage instanceof TextMessage) {
                    msg = (TextMessage) rcvMessage;
                    String orderStr = msg.getBody(String.class);
                    Order order = Transformers.jsonToOrder(orderStr);
                    order.getItemList().forEach(orderItem -> {
                        int old_quantity = catalogService.getCatalogItemById(orderItem.getProductId()).getInventory().getQuantity();
                        int new_quantity = old_quantity - orderItem.getQuantity();
                        if (new_quantity < LOW_THRESHOLD) {
                            System.out.println("Inventory for item " + orderItem.getProductId() + " is below threshold (" + LOW_THRESHOLD + "), contact supplier!");
                        } else {
                            orderItem.setQuantity(new_quantity);
                        }
                    });
                }


            } catch (JMSException jmse) {
                System.err.println("An exception occurred: " + jmse.getMessage());
            }
        }
    }
    }
"""

# %% [markdown]
# This rule flags suggests migrating javaee JMS referesnces with Quarkus specific ones.

# %%
hint_to_migrate="""\
    
  description:  References to JavaEE/JakartaEE JMS elements should be removed and replaced with their Quarkus SmallRye/Microprofile equivalents.
  message: |
   References to JavaEE/JakartaEE JMS elements should be removed and replaced with their Quarkus SmallRye/Microprofile equivalents.

    """

summary_of_changes="""\
Remove Deprecated APIs: Identify and remove any Java EE components and replace them with Quarkus or MicroProfile equivalents.
Use Annotations: Leverage Quarkus annotations like @Incoming, @ApplicationScoped, and @Transactional for better integration and functionality.
Logging: Utilize org.jboss.logging.Logger for logging instead of traditional Java logging or System.out.
Error Handling: Implement robust error handling with logging and exception management.
Testing: Ensure that the refactored code is thoroughly tested to confirm that it behaves as expected in the new environment.
"""

# %% [markdown]
# Similar example showing before and after migration

# %%
example_before_code="""\

@MessageDriven(
    activationConfig = {
        @ActivationConfigProperty(propertyName = "destinationLookup", propertyValue = "jms/queue/myQueue"), // JNDI lookup
        @ActivationConfigProperty(propertyName = "destinationType", propertyValue = "jakarta.jms.Queue")
        // Other properties like connectionFactoryLookup, acknowledgeMode might be needed depending on the server
    }
)
public class SimpleQueueMDB implements MessageListener {

    private static final Logger log = Logger.getLogger(SimpleQueueMDB.class.getName());

    @Override
    public void onMessage(Message message) {
        try {
            if (message instanceof TextMessage) {
                TextMessage textMessage = (TextMessage) message;
                String text = textMessage.getText();
                log.log(Level.INFO, "MDB Received: {0}", text);
               
                processPayload(text);
            } else {
                log.log(Level.WARNING, "MDB Received non-text message: {0}", message);
            }
            // Container typically acknowledges based on configuration (default AUTO_ACKNOWLEDGE implicit here)
        } catch (Exception e) {
            log.log(Level.SEVERE, "MDB Error processing message", e);

        }
    }
}

"""

example_after_code="""\
import jakarta.enterprise.context.ApplicationScoped;
import org.eclipse.microprofile.reactive.messaging.Incoming;
import org.jboss.logging.Logger;

@ApplicationScoped
public class SimpleQueueListener {

    private static final Logger log = Logger.getLogger(SimpleQueueListener.class);
    @Incoming("my-queue-in")
    public void consume(String payload) { 
        log.infof("Reactive Listener Received: %s", payload);
        try {

            processPayload(payload);

        } catch (Exception e) {
            log.errorf(e, "Reactive Listener Error processing message: %s", payload);
            throw new RuntimeException("Processing failed for: " + payload, e);
        }
    }

}

"""

# %%
source="javaee"
target="quarkus"

# %%
prompt = f"""

The following java code needs to be migrated from {source} to {target}.

```java
{before_code}
```
I will provide you with an example before/after code migration
```java
{example_before_code}
{example_after_code}
```
Use the following hint's message and summary of changes from a previous migration to migrate. 

{hint_to_migrate}
{summary_of_changes}

Also, remove the deprecated and unused APIs and suggest the correct alternatives based on the migration needs. 

Can you provide a refactored version of {before_code} that is compatible with {target}?
Also, create a step by step process for the above migration? Summarize and create a hint with the changes.

"""

# %%
response = await rendered_llm_call(prompt)
# Out:
# To migrate the given code from Java EE to Quarkus, we need to replace the JMS related imports and annotations with their Quarkus equivalents. Here is the refactored version of the code:
#
# ```java
# import org.eclipse.microprofile.reactive.messaging.Incoming;
# import org.jboss.logging.Logger;
#
# public class InventoryNotificationMDB {
#
#     private static final int LOW_THRESHOLD = 50;
#
#     @Inject
#     private CatalogService catalogService;
#
#     public void onMessage(String orderStr) {
#         try {
#             System.out.println("received message inventory");
#             Order order = Transformers.jsonToOrder(orderStr);
#             order.getItemList().forEach(orderItem -> {
#                 int old_quantity = catalogService.getCatalogItemById(orderItem.getProductId()).getInventory().getQuantity();
#                 int new_quantity = old_quantity - orderItem.getQuantity();
#                 if (new_quantity < LOW_THRESHOLD) {
#                     System.out.println("Inventory for item " + orderItem.getProductId() + " is below threshold (" + LOW_THRESHOLD + "), contact supplier!");
#                 } else {
#                     orderItem.setQuantity(new_quantity);
#                 }
#             });
#         } catch (Exception e) {
#             System.err.println("An exception occurred: " + e.getMessage());
#         }
#     }
# }
# ```
#
# Step by step process for the migration:
#
# 1. Replace the import statement `import javax.jms.*` with `import org.eclipse.microprofile.reactive.messaging.Incoming;` and `import org.jboss.logging.Logger;`.
# 2. Remove the `implements MessageListener` interface from the class declaration.
# 3. Remove the JMS related properties and variables like `JNDI_FACTORY`, `JMS_FACTORY`, `TOPIC`, `TopicConnection`, `TopicSession`, and `TopicSubscriber`.
# 4. Modify the `onMessage` method to accept a `String` parameter instead of a `Message` parameter.
# 5. Update the method logic to process the `orderStr` directly instead of extracting it from a `TextMessage`.
# 6. Handle exceptions using proper error handling techniques like logging.
#
# Hint for the changes:
# - Replace Java EE JMS imports with Quarkus MicroProfile Reactive Messaging imports.
# - Remove JMS related properties and variables.
# - Modify the method signature to accept a `String` parameter.
# - Update the method logic to process the message directly.
# - Implement proper error handling using logging.
