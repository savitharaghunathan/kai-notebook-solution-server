# %%
# %pip uninstall kai -y
# %pip install --no-cache-dir git+https://github.com/konveyor/kai.git@main
# %pip install python-dotenv
# Out:
# Found existing installation: kai 0.1.1.dev4+g9e2ca63
# Uninstalling kai-0.1.1.dev4+g9e2ca63:
#   Successfully uninstalled kai-0.1.1.dev4+g9e2ca63
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/konveyor/kai.git@main
#   Cloning https://github.com/konveyor/kai.git (to revision main) to /private/var/folders/4f/bv2hh9jd44b94_4zf2qby2sh0000gn/T/pip-req-build-77_s8aju
#   Running command git clone --filter=blob:none --quiet https://github.com/konveyor/kai.git /private/var/folders/4f/bv2hh9jd44b94_4zf2qby2sh0000gn/T/pip-req-build-77_s8aju
#   Resolved https://github.com/konveyor/kai.git to commit 9e2ca639af9c7077077e20a4da4144aa64eede6f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: aiohttp==3.9.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (3.9.3)
# Requirement already satisfied: gitpython==3.1.43 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (3.1.43)
# Requirement already satisfied: pydantic==2.10.6 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (2.10.6)
# Requirement already satisfied: pydantic-settings==2.4.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (2.4.0)
# Requirement already satisfied: requests==2.32.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (2.32.3)
# Requirement already satisfied: pygments==2.18.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (2.18.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (2.8.2)
# Requirement already satisfied: Jinja2==3.1.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (3.1.4)
# Requirement already satisfied: langchain==0.3.19 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.3.19)
# Requirement already satisfied: langchain-community==0.3.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.3.1)
# Requirement already satisfied: langchain-openai==0.3.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.3.3)
# Requirement already satisfied: langchain-ollama==0.2.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.2.3)
# Requirement already satisfied: langchain-google-genai==2.0.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (2.0.9)
# Requirement already satisfied: langchain-aws==0.2.11 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.2.11)
# Requirement already satisfied: langchain-experimental==0.3.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.3.2)
# Requirement already satisfied: langchain-deepseek-official==0.1.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.1.0)
# Requirement already satisfied: gunicorn==22.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (22.0.0)
# Requirement already satisfied: tree-sitter==0.22.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.22.3)
# Requirement already satisfied: tree-sitter-java==0.21.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.21.0)
# Requirement already satisfied: sequoia-diff>=0.0.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.0.9)
# Requirement already satisfied: python-dotenv==1.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (1.0.1)
# Requirement already satisfied: pyyaml==6.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (6.0.1)
# Requirement already satisfied: lxml==5.3.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (5.3.0)
# Requirement already satisfied: boto3==1.36.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (1.36.9)
# Requirement already satisfied: opentelemetry-sdk==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (1.29.0)
# Requirement already satisfied: opentelemetry-api==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-asyncio==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.50b0)
# Requirement already satisfied: async-timeout==4.0.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (4.0.3)
# Requirement already satisfied: asgiref==3.7.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (3.7.2)
# Requirement already satisfied: unidiff==0.7.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from kai==0.1.1.dev4+g9e2ca63) (0.7.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1.dev4+g9e2ca63) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1.dev4+g9e2ca63) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1.dev4+g9e2ca63) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1.dev4+g9e2ca63) (6.4.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from aiohttp==3.9.3->kai==0.1.1.dev4+g9e2ca63) (1.20.0)
# Requirement already satisfied: botocore<1.37.0,>=1.36.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from boto3==1.36.9->kai==0.1.1.dev4+g9e2ca63) (1.36.26)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from boto3==1.36.9->kai==0.1.1.dev4+g9e2ca63) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from boto3==1.36.9->kai==0.1.1.dev4+g9e2ca63) (0.11.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from gitpython==3.1.43->kai==0.1.1.dev4+g9e2ca63) (4.0.12)
# Requirement already satisfied: packaging in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from gunicorn==22.0.0->kai==0.1.1.dev4+g9e2ca63) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from Jinja2==3.1.4->kai==0.1.1.dev4+g9e2ca63) (3.0.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.35 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (0.3.53)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (0.1.147)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (8.5.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (1.26.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-community==0.3.1->kai==0.1.1.dev4+g9e2ca63) (0.6.7)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (1.2.0)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (0.8.5)
# Requirement already satisfied: ollama<1,>=0.4.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-ollama==0.2.3->kai==0.1.1.dev4+g9e2ca63) (0.4.8)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-openai==0.3.3->kai==0.1.1.dev4+g9e2ca63) (1.75.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-openai==0.3.3->kai==0.1.1.dev4+g9e2ca63) (0.9.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-api==1.29.0->kai==0.1.1.dev4+g9e2ca63) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-api==1.29.0->kai==0.1.1.dev4+g9e2ca63) (8.5.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev4+g9e2ca63) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev4+g9e2ca63) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asyncio==0.50b0->kai==0.1.1.dev4+g9e2ca63) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asyncio==0.50b0->kai==0.1.1.dev4+g9e2ca63) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-asyncio==0.50b0->kai==0.1.1.dev4+g9e2ca63) (1.17.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-sdk==1.29.0->kai==0.1.1.dev4+g9e2ca63) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from pydantic==2.10.6->kai==0.1.1.dev4+g9e2ca63) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from pydantic==2.10.6->kai==0.1.1.dev4+g9e2ca63) (2.27.2)
# Requirement already satisfied: six>=1.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from python-dateutil==2.8.2->kai==0.1.1.dev4+g9e2ca63) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1.dev4+g9e2ca63) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1.dev4+g9e2ca63) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1.dev4+g9e2ca63) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from requests==2.32.3->kai==0.1.1.dev4+g9e2ca63) (2025.1.31)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev4+g9e2ca63) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev4+g9e2ca63) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev4+g9e2ca63) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev4+g9e2ca63) (1.29.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp==1.29.0->kai==0.1.1.dev4+g9e2ca63) (5.29.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1->kai==0.1.1.dev4+g9e2ca63) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1->kai==0.1.1.dev4+g9e2ca63) (0.9.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython==3.1.43->kai==0.1.1.dev4+g9e2ca63) (5.0.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (0.6.15)
# Requirement already satisfied: google-api-core in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (2.24.2)
# Requirement already satisfied: google-api-python-client in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (2.167.0)
# Requirement already satisfied: google-auth>=2.15.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (2.39.0)
# Requirement already satisfied: tqdm in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (1.26.1)
# Requirement already satisfied: zipp>=3.20 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api==1.29.0->kai==0.1.1.dev4+g9e2ca63) (3.21.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.35->langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1.dev4+g9e2ca63) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1.dev4+g9e2ca63) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1.dev4+g9e2ca63) (0.9.0)
# Requirement already satisfied: sniffio in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.3->kai==0.1.1.dev4+g9e2ca63) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.3->kai==0.1.1.dev4+g9e2ca63) (2024.11.6)
# Requirement already satisfied: propcache>=0.2.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from yarl<2.0,>=1.0->aiohttp==3.9.3->kai==0.1.1.dev4+g9e2ca63) (0.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (4.9.1)
# Requirement already satisfied: httpcore==1.* in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.35->langchain==0.3.19->kai==0.1.1.dev4+g9e2ca63) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1->kai==0.1.1.dev4+g9e2ca63) (1.0.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (4.1.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.9->kai==0.1.1.dev4+g9e2ca63) (0.6.1)
# Building wheels for collected packages: kai
#   Building wheel for kai (pyproject.toml) ... done
#   Created wheel for kai: filename=kai-0.1.1.dev4+g9e2ca63-py3-none-any.whl size=4425694 sha256=978ee71620396852f485991e1fefba4047ea368793d679fd5d33512545f5bfa0
#   Stored in directory: /private/var/folders/4f/bv2hh9jd44b94_4zf2qby2sh0000gn/T/pip-ephem-wheel-cache-j44110sp/wheels/7a/5a/5e/746d82c99334b9ca71a121d123b53f96cb34d14e0b5280cb9a
# Successfully built kai
# Installing collected packages: kai
# Successfully installed kai-0.1.1.dev4+g9e2ca63
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in /Users/sraghuna/local_dev/kai-notebook-solution-server/.venv/lib/python3.13/site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import display, Markdown
from kai.llm_interfacing.model_provider import ModelProvider
from kai.kai_config import KaiConfigModels, SupportedModelProviders
from dotenv import load_dotenv
load_dotenv() 

# Initialize the model provider using GPT-4o via OpenAI
model = ModelProvider.from_config(KaiConfigModels(
    provider=SupportedModelProviders.CHAT_OPENAI,
    args={"model": "gpt-3.5-turbo"},
))

# Async rendering function for displaying the response
async def rendered_llm_call(prompt: str):
    response = await model.ainvoke_llm(prompt)
    display(Markdown(response.content))
    return response

# %%
before_code = """\
import org.springframework.context.annotation.Bean;
import org.springframework.context.annotation.Configuration;
import org.springframework.security.config.annotation.authentication.builders.AuthenticationManagerBuilder;
import org.springframework.security.config.annotation.web.configuration.EnableWebSecurity;
import org.springframework.security.config.annotation.web.configuration.WebSecurityConfigurerAdapter;
import org.springframework.security.crypto.bcrypt.BCryptPasswordEncoder;
import org.springframework.security.crypto.password.PasswordEncoder;

@Configuration
@EnableWebSecurity
public class SecurityConfig extends WebSecurityConfigurerAdapter {
    @Override
    protected void configure(AuthenticationManagerBuilder auth) throws Exception {
        auth.inMemoryAuthentication()
            .withUser("user")
            .password(passwordEncoder().encode("password"))
            .roles("USER");
    }

    @Bean
    public PasswordEncoder passwordEncoder() {
        return new BCryptPasswordEncoder();
    }
}
"""

# %%
analysis_rule=""""\
    
  ruleID: spring-security-replace-authenticationmanagerbuilder-00001
  description: configure(AuthenticationManagerBuilder) override is discouraged since Spring Security 5.7.
  category: mandatory
  effort: 2
  labels:
    - konveyor.io/source=spring-boot2
    - konveyor.io/target=spring-boot3+
  message: |
    Overriding `configure(AuthenticationManagerBuilder)` is **discouraged** in Spring Security 5.7.
    Instead, define a `UserDetailsService` and `PasswordEncoder` bean.
    ```
  when:
    java.referenced:
      location: METHOD
      pattern: configure(org.springframework.security.config.annotation.authentication.builders.AuthenticationManagerBuilder) *
    """

# %%
prompt = f"""
```java
{before_code}
```

{analysis_rule}

Can you me a fix for this issue and update the source code?

"""

# %%
response = await rendered_llm_call(prompt)
# Out:
# ```java
# import org.springframework.context.annotation.Bean;
# import org.springframework.context.annotation.Configuration;
# import org.springframework.security.config.annotation.web.configuration.EnableWebSecurity;
# import org.springframework.security.config.annotation.web.configuration.WebSecurityConfigurerAdapter;
# import org.springframework.security.crypto.bcrypt.BCryptPasswordEncoder;
# import org.springframework.security.crypto.password.PasswordEncoder;
#
# @Configuration
# @EnableWebSecurity
# public class SecurityConfig extends WebSecurityConfigurerAdapter {
#
#     @Bean
#     public PasswordEncoder passwordEncoder() {
#         return new BCryptPasswordEncoder();
#     }
# }
#
# ```
# In the above code snippet, the `configure(AuthenticationManagerBuilder)` method has been removed as it is discouraged in Spring Security 5.7. Instead, a `PasswordEncoder` bean has been defined using the `BCryptPasswordEncoder`. This is the recommended approach for handling authentication in Spring Security 5.7 and above.
